# %%
# 각 코드 셀의 실행시간 측정 모듈
# !pip install ipython-autotime

# %load_ext autotime
# Out:
# ...
# time: 2.66 ms (started: 2022-03-21 14:45:05 +00:00)

# %% [markdown]
# * M4 original dataset download and extract

# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip "/content/drive/MyDrive/Colab Notebooks/N-BEATS/dataset/m4.zip" -d /content/dataset
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Archive:  /content/drive/MyDrive/Colab Notebooks/N-BEATS/dataset/m4.zip
#   inflating: /content/dataset/m4/Daily-test.csv
#   inflating: /content/dataset/m4/Daily-train.csv
#   inflating: /content/dataset/m4/Hourly-test.csv
#   inflating: /content/dataset/m4/Hourly-train.csv
#   inflating: /content/dataset/m4/m4_info.csv
#   inflating: /content/dataset/m4/Monthly-test.csv
#   inflating: /content/dataset/m4/Monthly-train.csv
#   inflating: /content/dataset/m4/Quarterly-test.csv
#   inflating: /content/dataset/m4/Quarterly-train.csv
#   inflating: /content/dataset/m4/Weekly-test.csv
#   inflating: /content/dataset/m4/Weekly-train.csv
#   inflating: /content/dataset/m4/Yearly-test.csv
#   inflating: /content/dataset/m4/Yearly-train.csv
# time: 15.7 s (started: 2022-03-21 14:45:08 +00:00)

# %% [markdown]
# * clone codes & import

# %%
# !git clone https://github.com/TaeniKim/nbeats_reproduce.git
# Out:
# Cloning into 'nbeats_reproduce'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 13 (delta 3), reused 12 (delta 2), pack-reused 0
# Unpacking objects: 100% (13/13), done.
# time: 717 ms (started: 2022-03-21 14:45:29 +00:00)

# %%
# make result directorys
# !mkdir /content/result/
# !mkdir /content/result/m4/
# !mkdir /content/result/m4/generic
# !mkdir /content/result/m4/interpritable
# Out:
# time: 454 ms (started: 2022-03-21 14:45:36 +00:00)

# %%
from nbeats_reproduce import nbeatsrepro
# Out:
# time: 5.93 s (started: 2022-03-21 14:45:39 +00:00)

# %%
# Set Config
m4cfg = nbeatsrepro.M4Config()
# Out:
# time: 1.5 ms (started: 2022-03-21 14:45:48 +00:00)

# %%
# M4 Dataset
m4cfg.pathDatasetOrg = r"/content/dataset/m4/"
m4cfg.pathDatasetDump = r"/content/dataset/m4/"
m4cfg.pathResult = r"/content/result/m4/"

m4dataset = nbeatsrepro.M4Dataset(path_org = m4cfg.pathDatasetOrg, path_dump = m4cfg.pathDatasetDump)
# Out:
# /content/nbeats_reproduce/nbeatsrepro.py:144: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array(list(ts_dict.values())).dump(cache_path)
# time: 58.7 s (started: 2022-03-21 14:45:51 +00:00)

# %%
# M4 Experiments
nbeatsrepro.m4experiments(m4cfg, m4dataset, 'generic')
# Out:
# /content/nbeats_reproduce/nbeatsrepro.py:299: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([v[~np.isnan(v)] for v in values[groups == group_name]])
# iter:1/15 	 loss:3.130
# iter:2/15 	 loss:32.144
# iter:3/15 	 loss:15.122
# iter:4/15 	 loss:8.626
# iter:5/15 	 loss:3.783
# iter:6/15 	 loss:4.436
# iter:7/15 	 loss:3.752
# iter:8/15 	 loss:3.050
# iter:9/15 	 loss:2.020
# iter:10/15 	 loss:2.245
# iter:11/15 	 loss:2.470
# iter:12/15 	 loss:2.539
# iter:13/15 	 loss:2.158
# iter:14/15 	 loss:1.740
# iter:15/15 	 loss:1.999
# Dump start: /content/result/m4/2022-03-21 144729+Yearly+2+MASE+
# iter:1/15 	 loss:0.126
# iter:2/15 	 loss:1.703
# iter:3/15 	 loss:0.671
# iter:4/15 	 loss:0.237
# iter:5/15 	 loss:0.200
# iter:6/15 	 loss:0.179
# ...

# %%
# copy result folder
# !cp -av '/content/result/m4/generic' '/content/drive/MyDrive/Colab Notebooks/N-BEATS/result/m4/generic'
